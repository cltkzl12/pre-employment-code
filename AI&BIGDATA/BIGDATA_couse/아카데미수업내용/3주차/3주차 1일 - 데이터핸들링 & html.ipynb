# %%
#데이터 핸들링 관련 3문제 나옴
import pandas as pd
import numpy as np
from numpy.random import randn

np.random.seed(1234)

df = pd.DataFrame(randn(10,2), columns = ['A','B'])

df['A']
# Out:
# 0    0.471435
# 1    1.432707
# 2   -0.720589
# 3    0.859588
# 4    0.015696
# 5    1.150036
# 6    0.953324
# 7   -0.334077
# 8    0.405453
# 9    1.321158
# Name: A, dtype: float64

# %%
df[['A']]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588
# 4  0.015696
# 5  1.150036
# 6  0.953324
# 7 -0.334077
# 8  0.405453
# 9  1.321158

# %%
df[0:5]
# Out:
#           A         B
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 2 -0.720589  0.887163
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685

# %%
df.loc[0:7,['A']]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588
# 4  0.015696
# 5  1.150036
# 6  0.953324
# 7 -0.334077

# %%
df.loc[:,['A']]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588
# 4  0.015696
# 5  1.150036
# 6  0.953324
# 7 -0.334077
# 8  0.405453
# 9  1.321158

# %%
df.loc[3:8]
# Out:
#           A         B
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 7 -0.334077  0.002118
# 8  0.405453  0.289092

# %%
df.loc[3:3]
# Out:
#           A         B
# 3  0.859588 -0.636524

# %%
df.iloc[0:7,[0]]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588
# 4  0.015696
# 5  1.150036
# 6  0.953324

# %%
df.iloc[:,[0]]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588
# 4  0.015696
# 5  1.150036
# 6  0.953324
# 7 -0.334077
# 8  0.405453
# 9  1.321158

# %%
df.iloc[3:8]
# Out:
#           A         B
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 7 -0.334077  0.002118

# %%
df.iloc[3:4]
# Out:
#           A         B
# 3  0.859588 -0.636524

# %%
df.query('A>0.5')
# Out:
#           A         B
# 1  1.432707 -0.312652
# 3  0.859588 -0.636524
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 9  1.321158 -1.546906

# %%
df.query('A>B')
# Out:
#           A         B
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 8  0.405453  0.289092
# 9  1.321158 -1.546906

# %%
df[df.A>df.B]
# Out:
#           A         B
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 8  0.405453  0.289092
# 9  1.321158 -1.546906

# %%
df.query('A>0.5 & B<0.0')
# Out:
#           A         B
# 1  1.432707 -0.312652
# 3  0.859588 -0.636524
# 6  0.953324 -2.021255
# 9  1.321158 -1.546906

# %%
df.query('A>0.5 | B<0.0')
# Out:
#           A         B
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 9  1.321158 -1.546906

# %%
df = pd.DataFrame(randn(10,4), columns = ['A','B','C','D'])

df['D']
# Out:
# 0   -0.208499
# 1   -1.142631
# 2    0.462060
# 3    2.007843
# 4    0.039513
# 5    0.152631
# 6    0.984920
# 7   -0.399965
# 8   -0.081947
# 9   -0.511881
# Name: D, dtype: float64

# %%
df[['D']]
# Out:
#           D
# 0 -0.208499
# 1 -1.142631
# 2  0.462060
# 3  2.007843
# 4  0.039513
# 5  0.152631
# 6  0.984920
# 7 -0.399965
# 8 -0.081947
# 9 -0.511881

# %%
df.loc[0:5,['A']]
# Out:
#           A
# 0 -0.974236
# 1  1.033801
# 2  0.211883
# 3  0.704228
# 4  0.226963
# 5  0.464392

# %%
df.iloc[0:5,[0]]
# Out:
#           A
# 0 -0.974236
# 1  1.033801
# 2  0.211883
# 3  0.704228
# 4  0.226963

# %%
df.query('D>0.5')
# Out:
#           A         B         C         D
# 3  0.704228  0.523508 -0.926254  2.007843
# 6  0.164530 -0.430096  0.767369  0.984920

# %%
df[df.A>df.B]
# Out:
#           A         B         C         D
# 1  1.033801 -2.400454  2.030604 -1.142631
# 3  0.704228  0.523508 -0.926254  2.007843
# 4  0.226963 -1.152659  0.631979  0.039513
# 5  0.464392 -3.563517  1.321106  0.152631
# 6  0.164530 -0.430096  0.767369  0.984920

# %%
df = pd.DataFrame({'ABC':['A','B','C','D'],
                  'abc':['a','b','c','d'],
                  'group1':['G1','G2','G3','G4'],
                  'value1':[11,13,12,14],
                  'val1_mod':[0.231,0.197,0.213,0.199]})

df
# Out:
#   ABC abc group1  value1  val1_mod
# 0   A   a     G1      11     0.231
# 1   B   b     G2      13     0.197
# 2   C   c     G3      12     0.213
# 3   D   d     G4      14     0.199

# %%
df.filter(items=['group1','value1'])
# Out:
#   group1  value1
# 0     G1      11
# 1     G2      13
# 2     G3      12
# 3     G4      14

# %%
df.filter(regex='1', axis=1)
# Out:
#   group1  value1  val1_mod
# 0     G1      11     0.231
# 1     G2      13     0.197
# 2     G3      12     0.213
# 3     G4      14     0.199

# %%
df.filter(regex='1$',axis=1)
# Out:
#   group1  value1
# 0     G1      11
# 1     G2      13
# 2     G3      12
# 3     G4      14

# %%
df.filter(like='a',axis=1)
# Out:
#   abc  value1  val1_mod
# 0   a      11     0.231
# 1   b      13     0.197
# 2   c      12     0.213
# 3   d      14     0.199

# %%
df.filter(regex='[Aa]',axis=1)
# Out:
#   ABC abc  value1  val1_mod
# 0   A   a      11     0.231
# 1   B   b      13     0.197
# 2   C   c      12     0.213
# 3   D   d      14     0.199

# %%
df.mask(df.value1>12)
# Out:
#    ABC  abc group1  value1  val1_mod
# 0    A    a     G1    11.0     0.231
# 1  NaN  NaN    NaN     NaN       NaN
# 2    C    c     G3    12.0     0.213
# 3  NaN  NaN    NaN     NaN       NaN

# %%
df.mask(df.abc == 'a')
# Out:
#    ABC  abc group1  value1  val1_mod
# 0  NaN  NaN    NaN     NaN       NaN
# 1    B    b     G2    13.0     0.197
# 2    C    c     G3    12.0     0.213
# 3    D    d     G4    14.0     0.199

# %%
df.mask(cond = df.value1>12,
       other =999)
# Out:
#    ABC  abc group1  value1  val1_mod
# 0    A    a     G1      11     0.231
# 1  999  999    999     999   999.000
# 2    C    c     G3      12     0.213
# 3  999  999    999     999   999.000

# %%
# concat , append
df1 = pd.DataFrame({'A':['A0','A1','A2','A3'],
                   'B':['B0','B1','B2','B3'],
                   'C':['C0','C1','C2','C3'],
                   'D':['D0','D1','D2','D3']},
                       index = [0,1,2,3])
df2 = pd.DataFrame({'A':['A4','A5','A6','A7'],
                   'B':['B4','B5','B6','B7'],
                   'C':['C4','C5','C6','C7'],
                   'D':['D4','D5','D6','D7']},
                       index = [4,5,6,7])
df3 = pd.DataFrame({'A':['A8','A9','A10','A11'],
                   'B':['B8','B9','B10','B11'],
                   'C':['C8','C9','C10','C11'],
                   'D':['D8','D9','D10','D11']},
                        index = [8,9,10,11])

# %%
result = pd.concat([df1,df2,df3])
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat([df1,df2,df3], axis=1)
result
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
result = pd.concat([df1,df2,df3],axis=1 , ignore_index = True)
result.columns = ['col_'+str(i) for i in range(len(result))]
result
# Out:
#    col_0 col_1 col_2 col_3 col_4 col_5 col_6 col_7 col_8 col_9 col_10 col_11
# 0     A0    B0    C0    D0   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 1     A1    B1    C1    D1   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 2     A2    B2    C2    D2   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3     A3    B3    C3    D3   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 4    NaN   NaN   NaN   NaN    A4    B4    C4    D4   NaN   NaN    NaN    NaN
# 5    NaN   NaN   NaN   NaN    A5    B5    C5    D5   NaN   NaN    NaN    NaN
# 6    NaN   NaN   NaN   NaN    A6    B6    C6    D6   NaN   NaN    NaN    NaN
# 7    NaN   NaN   NaN   NaN    A7    B7    C7    D7   NaN   NaN    NaN    NaN
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    A8    B8     C8     D8
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    A9    B9     C9     D9
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   A10   B10    C10    D10
# ...

# %%
# concat , append
df1 = pd.DataFrame({'A':['A0','A1','A2','A3'],
                   'B':['B0','B1','B2','B3'],
                   'C':['C0','C1','C2','C3'],
                   'D':['D0','D1','D2','D3']},
                       index = [0,1,2,3])
df2 = pd.DataFrame({'E':['E4','E5','E6','E7'],
                   'F':['F4','F5','F6','F7'],
                   'G':['G4','G5','G6','G7'],
                   'H':['H4','H5','H6','H7']},
                       index = [0,1,2,3])
df3 = pd.DataFrame({'I':['I8','I9','I10','I11'],
                   'J':['J8','J9','J10','J11'],
                   'K':['K8','K9','K10','K11'],
                   'L':['L8','L9','L10','L11']},
                        index = [0,1,2,3])

# %%
result = pd.concat([df1,df2,df3],axis=1)
result
# Out:
#     A   B   C   D   E   F   G   H    I    J    K    L
# 0  A0  B0  C0  D0  E4  F4  G4  H4   I8   J8   K8   L8
# 1  A1  B1  C1  D1  E5  F5  G5  H5   I9   J9   K9   L9
# 2  A2  B2  C2  D2  E6  F6  G6  H6  I10  J10  K10  L10
# 3  A3  B3  C3  D3  E7  F7  G7  H7  I11  J11  K11  L11

# %%
result = pd.concat([df1,df2,df3], axis=1)
result
# Out:
#       A    B    C    D    E    F    G    H    I    J    K    L
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   E4   F4   G4   H4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   E5   F5   G5   H5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   E6   F6   G6   H6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   E7   F7   G7   H7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   I8   J8   K8   L8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   I9   J9   K9   L9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  I10  J10  K10  L10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  I11  J11  K11  L11

# %%
result = pd.concat([df1,df2,df3],axis=1 , ignore_index = True)
result.columns = ['col_'+str(i) for i in range(len(result))]
result
# Out:
#    col_0 col_1 col_2 col_3 col_4 col_5 col_6 col_7 col_8 col_9 col_10 col_11
# 0     A0    B0    C0    D0   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 1     A1    B1    C1    D1   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 2     A2    B2    C2    D2   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3     A3    B3    C3    D3   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 4    NaN   NaN   NaN   NaN    E4    F4    G4    H4   NaN   NaN    NaN    NaN
# 5    NaN   NaN   NaN   NaN    E5    F5    G5    H5   NaN   NaN    NaN    NaN
# 6    NaN   NaN   NaN   NaN    E6    F6    G6    H6   NaN   NaN    NaN    NaN
# 7    NaN   NaN   NaN   NaN    E7    F7    G7    H7   NaN   NaN    NaN    NaN
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    I8    J8     K8     L8
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    I9    J9     K9     L9
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   I10   J10    K10    L10
# ...

# %%
import pandas as pd
left = pd.DataFrame({'key1':['K0','K1','K2','K3'],
                    'key2': ['K0','K1','K0','K1'],
                    'A':['A0','A1','A2','A3'],
                    'B':['B0','B1','B2','B3']})
right = pd.DataFrame({'key1':['K0','K1','K2','K3'],
                    'key2': ['K0','K0','K0','K0'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']})

pd.merge(left,right , on = ['key1','key2'])
# result
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K2   K0  A2  B2  C2  D2

# %%
result = pd.merge(left , right , on = ['key1','key2'], how = 'left')

result
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K1   K1  A1  B1  NaN  NaN
# 2   K2   K0  A2  B2   C2   D2
# 3   K3   K1  A3  B3  NaN  NaN

# %%
result = pd.merge(left , right , on = ['key1','key2'], how = 'right')

result
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K2   K0   A2   B2  C2  D2
# 2   K1   K0  NaN  NaN  C1  D1
# 3   K3   K0  NaN  NaN  C3  D3

# %%
result = pd.merge(left , right , on = ['key1','key2'], how = 'outer')

result
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K1   K1   A1   B1  NaN  NaN
# 2   K2   K0   A2   B2   C2   D2
# 3   K3   K1   A3   B3  NaN  NaN
# 4   K1   K0  NaN  NaN   C1   D1
# 5   K3   K0  NaN  NaN   C3   D3

# %%
result = pd.merge(left , right , on = ['key1','key2'], how = 'outer', indicator = True)

result
# Out:
#   key1 key2    A    B    C    D      _merge
# 0   K0   K0   A0   B0   C0   D0        both
# 1   K1   K1   A1   B1  NaN  NaN   left_only
# 2   K2   K0   A2   B2   C2   D2        both
# 3   K3   K1   A3   B3  NaN  NaN   left_only
# 4   K1   K0  NaN  NaN   C1   D1  right_only
# 5   K3   K0  NaN  NaN   C3   D3  right_only

# %%
left = pd.DataFrame({'key1':[1,2,3,4],
                    'A':['A0','A1','A2','A3'],
                    'B':['B0','B1','B2','B3']})
right = pd.DataFrame({
                    
                    'C':['C1','C2','C5'],
                    'D':['D1','D2','D5']},
                    index = [1,2,5])

# %%
#기본이 left outer join
result = left.join(right)
result
# Out:
#    key1   A   B    C    D
# 0     1  A0  B0  NaN  NaN
# 1     2  A1  B1   C1   D1
# 2     3  A2  B2   C2   D2
# 3     4  A3  B3  NaN  NaN

# %%
result = left.join(right,how = 'right')
result
# Out:
#    key1    A    B   C   D
# 1   2.0   A1   B1  C1  D1
# 2   3.0   A2   B2  C2  D2
# 5   NaN  NaN  NaN  C5  D5

# %%
result = left.join(right , how = 'inner')
result
# Out:
#    key1   A   B   C   D
# 1     2  A1  B1  C1  D1
# 2     3  A2  B2  C2  D2

# %%
result = left.join(right , how = 'outer')
result
# Out:
#    key1    A    B    C    D
# 0   1.0   A0   B0  NaN  NaN
# 1   2.0   A1   B1   C1   D1
# 2   3.0   A2   B2   C2   D2
# 3   4.0   A3   B3  NaN  NaN
# 5   NaN  NaN  NaN   C5   D5

# %%
result = left.join(right, on = 'key1')
result
# Out:
#    key1   A   B    C    D
# 0     1  A0  B0   C1   D1
# 1     2  A1  B1   C2   D2
# 2     3  A2  B2  NaN  NaN
# 3     4  A3  B3  NaN  NaN

# %%
result2 = pd.merge(left, right , left_on = 'key1', right_index=True,how='left')
result2
# Out:
#    key1   A   B    C    D
# 0     1  A0  B0   C1   D1
# 1     2  A1  B1   C2   D2
# 2     3  A2  B2  NaN  NaN
# 3     4  A3  B3  NaN  NaN

# %%
df = pd.DataFrame({'index': [1,1,1,2,2,2],
                  'column':['col_1','col_2','col_3','col_1','col_2','col_3'],
                  'value_1': [1,2,3,4,5,6],
                  'value_2':['x','y','z','q','w','t']})

df
# Out:
#    index column  value_1 value_2
# 0      1  col_1        1       x
# 1      1  col_2        2       y
# 2      1  col_3        3       z
# 3      2  col_1        4       q
# 4      2  col_2        5       w
# 5      2  col_3        6       t

# %%
df.pivot(index='index', columns = 'column',values = 'value_1')
# Out:
# column  col_1  col_2  col_3
# index
# 1           1      2      3
# 2           4      5      6

# %%
df.pivot(index='index', columns = 'column')['value_1']
# Out:
# column  col_1  col_2  col_3
# index
# 1           1      2      3
# 2           4      5      6

# %%
df.pivot(index='index', columns='column', values=['value_1','value_2'])
# Out:
#        value_1             value_2
# column   col_1 col_2 col_3   col_1 col_2 col_3
# index
# 1            1     2     3       x     y     z
# 2            4     5     6       q     w     t

# %%
df.pivot(index='index', columns='column')
# Out:
#        value_1             value_2
# column   col_1 col_2 col_3   col_1 col_2 col_3
# index
# 1            1     2     3       x     y     z
# 2            4     5     6       q     w     t

# %%
df.pivot(columns='column',values='value_1')
# Out:
# column  col_1  col_2  col_3
# 0         1.0    NaN    NaN
# 1         NaN    2.0    NaN
# 2         NaN    NaN    3.0
# 3         4.0    NaN    NaN
# 4         NaN    5.0    NaN
# 5         NaN    NaN    6.0

# %%
df.melt(id_vars=['index','column'])
# Out:
#     index column variable value
# 0       1  col_1  value_1     1
# 1       1  col_2  value_1     2
# 2       1  col_3  value_1     3
# 3       2  col_1  value_1     4
# 4       2  col_2  value_1     5
# 5       2  col_3  value_1     6
# 6       1  col_1  value_2     x
# 7       1  col_2  value_2     y
# 8       1  col_3  value_2     z
# 9       2  col_1  value_2     q
# 10      2  col_2  value_2     w
# 11      2  col_3  value_2     t

# %%
df.melt(id_vars = ['index','column'],
       value_vars=['value_1'])
# Out:
#    index column variable  value
# 0      1  col_1  value_1      1
# 1      1  col_2  value_1      2
# 2      1  col_3  value_1      3
# 3      2  col_1  value_1      4
# 4      2  col_2  value_1      5
# 5      2  col_3  value_1      6

# %%
file = pd.read_csv('통계수업파일/FITNESS.csv')
gender= ['F','M']
file = file.query('GENDER == @gender')
file.head()
# Out:
#      NAME GENDER  AGE  AGEGROUP  WEIGHT     OXY  RUNTIME  RUNPULSE  RSTPULSE  \
# 0   Donna      F   42        40   68.15  59.571     8.17       166        40
# 2  Luanne      F   43        40   85.84  54.297     8.65       156        45
# 3    Mimi      F   50        50   70.87  54.625     8.92       146        48
# 4   Chris      M   49        40   70.00  49.156     8.95       180        44
# 5   Allen      M   38        30   89.02  49.874     9.22       178        55
#
#    MAXPULSE
# 0       172
# 2       168
# 3       155
# 4       185
# 5       180

# %%
FILE = file[['AGEGROUP','WEIGHT','GENDER']]

FILE = FILE.groupby(['AGEGROUP','GENDER'])['WEIGHT'].agg(['mean'])
FILE
# Out:
#                       mean
# AGEGROUP GENDER
# 30       F       75.980000
#          M       82.758000
# 40       F       72.943750
#          M       79.342000
# 50       F       70.856667
#          M       79.426000

# %%
FILE = FILE.reset_index(level = ['GENDER', 'AGEGROUP'])
FILE
# Out:
#    AGEGROUP GENDER       mean
# 0        30      F  75.980000
# 1        30      M  82.758000
# 2        40      F  72.943750
# 3        40      M  79.342000
# 4        50      F  70.856667
# 5        50      M  79.426000

# %%
FILE.pivot(index = 'AGEGROUP', columns = 'GENDER')['mean']
# Out:
# GENDER            F       M
# AGEGROUP
# 30        75.980000  82.758
# 40        72.943750  79.342
# 50        70.856667  79.426

# %% [markdown]
# # Text 마이닝 시작!
# conda create -n nlp_tutorial python=3.7

# %% [markdown]
# <html>
#
#   <head>
#     <title> 안녕 하세요 ! </title>
#   </head>
#
#   <body>
#     <h1>
#       졸려워
#     </h1>
#     <h2>
#       졸려워
#     </h2>
#     <h3>
#       졸려워
#     </h3>
#
#     <a href="http://www.naver.com">
#       네이버
#     </a>
#     <table border=1>
#       <tr>
#         <th>항목</th>
#         <th>영용짱</th>
#       </tr>
#       <tr>
#         <th>메롱</th>
#       </tr>
#     </table>
#
#   </body>
#
# </html>

# %% [markdown]
# <html>
#
#   <head>
#     <title> 안녕 하세요 ! </title>
#   </head>
#
#   <body>
#
#     <table border=6>
#       <tr>
#         <th>재무정보</th>
#         <th>2017</th>
#         <th>2018</th>
#         <th>2019</th>
#       </tr>
#       <tr>
#         <td>1</td>
#         <td>2</td>
#         <td>3</td>
#         <td>4</td>
#       </tr>
#     </table>
#
#   </body>
#
# </html>

# %%
import requests as rq
from bs4 import BeautifulSoup as bt

html = """ <ul>
<li> 뉴스 </li>
<li> 증권 </li>
<li> 사전 </li>
</ul>"""

# %%
soup = bt(html,'html5lib')
result = soup.select("li")
for i in result:
    print(i)
# Out:
# <li> 뉴스 </li>
# <li> 증권 </li>
# <li> 사전 </li>

# %%
html = """
<ul>
<li>1교시</li>
<li>2교시</li>

</ul>
<ol>
<li>3교시</li>
<li>4교시</li>
</ol>
"""

# %%
# nth-child(1) 하나만 들고오기 !
soup = bt(html, 'html5lib')
result = soup.select("ol>li:nth-child(1)")
for i in result:
    print(i.text)
# Out:
# "중국, 우한전세기 1대만 승인, 오늘 360명 귀국 목표"

# %%
url = "http://www.naver.com"
reponse = rq.get(url)
html = reponse.text
# print(dir(reponse))

# %%
soup = bt(html, 'html5lib')
result = soup.select("#PM_ID_serviceNavi > li:nth-child(4) > a > span.an_txt")
for i in result:
    print (i.text)
# Out:
# 부동산

# %%
#
# Out:
# [<span class="an_icon"></span>,
#  <span class="an_txt">사전</span>,
#  <span class="an_icon"></span>,
#  <span class="an_txt">뉴스</span>,
#  <span class="an_icon"></span>,
#  <span class="an_txt">증권(금융)</span>,
#  <span class="an_icon"></span>,
#  <span class="an_txt">부동산</span>,
#  <span class="an_icon"></span>,
#  <span class="an_txt">지도</span>,
#  <span class="an_icon"></span>,
#  <span class="an_txt">영화</span>,
#  <span class="an_icon"></span>,
#  <span class="an_txt">뮤직</span>,
#  <span class="an_icon"></span>,
#  <span class="an_txt">책</span>,
#  <span class="an_icon"></span>,
#  <span class="an_txt">만화 / 웹툰</span>]

# %%
#today_main_news > div.hdline_news > ul > li:nth-child(1) > div.hdline_article_tit > a


url = "http://news.naver.com"
reponse = rq.get(url)
html = reponse.text


soup = bt(html, 'html5lib')
result = soup.select("#today_main_news > div.hdline_news > ul > li > div.hdline_article_tit > a")


for cnt,i in enumerate(result):
    print (str(cnt+1)+'.',i.text.strip())
# Out:
# 1. 송철호 "정치목적 왜곡수사, 무리한 기소 분노"…혐의 전면부인(종합)
# 2. 강원랜드 채용비리 닮은꼴…'권성동 무죄·염동열 유죄' 왜?
# 3. '우한 폐렴' 중국 하늘길 막힌다…대한항공까지 중단 결정
# 4. 서울 강남4구 아파트값 33주 만에 하락 전환
# 5. 메모리 반도체 불황에 직격탄…삼성전자 지난해 영업이익 '반토막'

# %%
url = "https://twitter.com/moonriver365"
reponse = rq.get(url)
html = reponse.text
html
# Out:
# '<!DOCTYPE html>\n<html lang="ko" data-scribe-reduced-action-queue="true">\n  <head>\n    \n    \n    \n    \n    \n    \n    \n    <meta charset="utf-8">\n      <script  nonce="Qp0jw999w7rctGK6hz8ojg==">\n        !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();\n      </script>\n    \n    \n  \n  <script id="bouncer_terminate_iframe" nonce="Qp0jw999w7rctGK6hz8ojg==">\n    if (window.top != window) {\n  window.top.postMessage({\'bouncer\': true, \'event\': \'complete\'}, \'*\');\n}\n  </script>\n  <script id="swift_action_queue" nonce="Qp0jw999w7rctGK6hz8ojg==">\n    !function(){function e(e){if(e||(e=window.event),!e)return!1;if(e.timestamp=(new Date).getTime(),!e.target&&e.srcElement&&(e.target=e.srcElement),document.documentElement.getAttribute("data-scribe-reduced-action-queue"))for(var t=e.target;t&&t!=document.body;)
# ...

# %%
soup = bt(html)
soup
# result = soup.select("#react-root > div > div > div > main > div > div > div > div.css-1dbjc4n.r-14lw9ot.r-1tlfku8.r-1ljd8xs.r-13l2t4g.r-1phboty.r-1jgb5lz.r-1ye8kvj.r-13qz1uu.r-184en5c > div > div > div > div > div:nth-child(3) > section > div > div > div > div:nth-child(2) > div > article > div > div>span")

# result
# Out:
# <!DOCTYPE html>
# <html data-scribe-reduced-action-queue="true" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <script nonce="Qp0jw999w7rctGK6hz8ojg==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>
# <script id="bouncer_terminate_iframe" nonce="Qp0jw999w7rctGK6hz8ojg==">
#     if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
# <script id="swift_action_queue" nonce="Qp0jw999w7rctGK6hz8ojg==">
# ...

# %%
end_price = [100,200,300,400,500,600]
for i in range(len(end_price)-2):
    print((end_price[i]+end_price[i+1]+end_price[i+2])/3)
# Out:
# 200.0
# 300.0
# 400.0
# 500.0

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


#크롬창을 킨다.
options = Options()
path = '/home/pirl/Downloads/chromedriver'
driver = webdriver.Chrome(path,chrome_options=options)
driver.set_window_size(1800,900)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: use options instead of chrome_options

# %%
driver.get('https://www.naver.com')
driver.find_element_by_css_selector("#PM_ID_serviceNavi > li:nth-child(4) > a > span.an_icon").click()
selector = '#content > div.section_group > div.section_l > div.news.NE\=a\:tdn > h3 > a'
driver.find_element_by_css_selector(selector).click()

# %%
#웹툰 들어가기
driver.get('https://www.naver.com')
selector = '#PM_ID_serviceNavi > li:nth-child(9) > a > span.an_icon'
driver.find_element_by_css_selector(selector).click()

# %%
#방탄 소년단 검색
driver.get('https://www.naver.com')
selector = '#query'
driver.find_element_by_css_selector(selector).send_keys("방탄소년단")
selector = '#search_btn > span.ico_search_submit'
driver.find_element_by_css_selector(selector).click()

# %%
import time
driver.get('http://ticket.interpark.com/')
selector = '#Nav_SearchWord'
driver.find_element_by_css_selector(selector).send_keys("아이유")
time.sleep(1)
selector = '#AllSearch > fieldset > div.box > a > img'
driver.find_element_by_css_selector(selector).click()

# %%
for i in range(5):
#     selector = '#playend_list > tr:nth-child('+str(i+1)+') > td.info_Play > div > dl > dt > h4 > a'
    selector = f'#playend_list > tr:nth-child({i+1}) > td.info_Play > div > dl > dt > h4 > a'
    print(driver.find_element_by_css_selector(selector).text)
# Out:
# 2019 아이유 11주년 팬미팅 ‘▶ ll ＆ U’ (PLAY, PAUSE AND U)
# 삼성카드 〈2018 홀가분 페스티벌〉
# 2018 이슬라이브 페스티벌
# 아이유 데뷔 9주년 팬미팅
# 2015 아이유 전국투어 앵콜 콘서트〈CHAT-SHIRE〉

# %%
driver.get("https://www.investing.com/indices/us-spx-500")
selector = '#leftColumn > div:nth-child(20) > article:nth-child(3) > div.textDiv > a'
driver.find_element_by_css_selector(selector).text
# Out:
# 'Asia Markets: Asian markets fall as Fed stays still, coronavirus keeps spreading'

# %%
# webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-370-0567dd71974e> in <module>
# ----> 1 webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()
#
# NameError: name 'Keys' is not defined

# %%
import time
driver.get('http://ticket.interpark.com/')
selector = '#Nav_SearchWord'
driver.find_element_by_css_selector(selector).send_keys("아이유")
time.sleep(1)
selector = '#AllSearch > fieldset > div.box > a > img'
driver.find_element_by_css_selector(selector).click()

# %%
html = driver.page_source
soup= bt(html)
# print(html)

# %%
selector = '#playend_list > tr:nth-child(1) > td.info_Play > div > dl > dt > h4 > a'

# %%
result = soup.select('#playend_list > tr:nth-child(1) > td.info_Play > div > dl > dt > h4 > a')
for i in result:
    print(i.text)
# Out:
# 2019 아이유 11주년 팬미팅 ‘▶ ll ＆ U’ (PLAY, PAUSE AND U)

# %%
get https://api.bithumb.com/public/ticker/{order_currency}_{payment_currency}

# %%
resp = rq.get('https://api.bithumb.com/public/ticker')
print(resp.text)
# Out:
# {"status":"0000","data":{"opening_price":"10654000","closing_price":"10647000","min_price":"10531000","max_price":"10773000","units_traded":"2827.14250141","acc_trade_value":"30052646843.3382","prev_closing_price":"10651000","units_traded_24H":"4556.8594557","acc_trade_value_24H":"48466273484.8211","fluctate_24H":"31000","fluctate_rate_24H":"0.29","date":"1580373349376"}}

# %%
data = resp.json()
print(data)
# Out:
# {'status': '0000', 'data': {'opening_price': '10654000', 'closing_price': '10647000', 'min_price': '10531000', 'max_price': '10773000', 'units_traded': '2827.14250141', 'acc_trade_value': '30052646843.3382', 'prev_closing_price': '10651000', 'units_traded_24H': '4556.8594557', 'acc_trade_value_24H': '48466273484.8211', 'fluctate_24H': '31000', 'fluctate_rate_24H': '0.29', 'date': '1580373349376'}}

# %%
print(data['data']['closing_price'])
# Out:
# 10647000

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


#크롬창을 킨다.
options = Options()
path = '/home/pirl/Downloads/chromedriver'
driver = webdriver.Chrome(path,chrome_options=options)
driver.set_window_size(1800,900)



#
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: use options instead of chrome_options

# %%
# driver.get('https://mart.baemin.com/goods/detail/3912')
tmp = []
# selector = 'root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > div.sc-jPPmml.heYxsi > section:nth-child(1) > div.sc-gjAXCV.gqHHfv > span > span'
# selector = '#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > div.sc-jPPmml.heYxsi > section:nth-child(1) > div.sc-gjAXCV.gqHHfv > span'
while(1):
    try:
        for j in range(1,100):
            selector = f'#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > section > div > a:nth-child({j+1})'
            driver.find_element_by_css_selector(selector).click()
            for i in range(1,11):
                selector = f'#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > div.sc-jPPmml.heYxsi > section:nth-child({i}) > div.sc-gjAXCV.gqHHfv > span'
                            
                text=driver.find_element_by_css_selector(selector).text
                if '배달' in text:
                    tmp.append(driver.find_element_by_css_selector(selector).text)
    except : break
    
#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > section > div > a:nth-child(3)
# driver.find_element_by_css_selector(selector).text
# selector = '#content > div.section_group > div.section_l > div.news.NE\=a\:tdn > h3 > a'
# driver.find_element_by_css_selector(selector).click()

# %%
selector = '#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > section > div > a:nth-child(2)'
driver.find_element_by_css_selector(selector).click()

# %%
selector = '#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > div.sc-jPPmml.heYxsi > section:nth-child(1) > div.sc-gjAXCV.gqHHfv > span'
tmp.append(driver.find_element_by_css_selector(selector).text)
tmp
# Out:
# ['앞전엔 본사에서 추천한 도시락을 써는데 \n뚜껑이 잘 맞질않아  고무줄로 두번 포장을 해야했는데 이번껀 조금단단한것 같아요 \n그래서 또 재주문 합니다.']

# %%
tmp
# Out:
# ['앞전엔 본사에서 추천한 도시락을 써는데 \n뚜껑이 잘 맞질않아  고무줄로 두번 포장을 해야했는데 이번껀 조금단단한것 같아요 \n그래서 또 재주문 합니다.',
#  '늘 잘 쓰고 있어요~',
#  '두껑과 본체 같이놓고 쓰는데 도시락 본체가 50개 1줄당 평규적으로 2~3개씩 항상 모자랍니다.\n공장에서 모르고 출고될수가 없는데\n꼭 확인해서 조치바랍니다~~\n두껑 남는거  많이 버립니다.',
#  '항상 사용하고 있습니다.\n근데몇박스 이상 주문시\n자체배송 시스템같은건없나요..\n택배기사님 벌써 3번 바뀌셨는데\n매번 몇박스씩들고\n헥헥 거리면서 앞으로도 계속 이렇게\n시키냐고하는데\n거참 돈주고시키는거지만 눈치보여서\n못시키겠네요..;',
#  '사용하고있는데 뚜껑몸통이  잘안맞는게  많아요  처음 뜯어서  쓸땐 잘맞았는데 쓰다보니 불량이 들어있는건지 안맞는게 종종나와요',
#  '좋아요^^',
#  '좋아요~♥',
#  '굿입니다~ ',
#  '짱이에요~~',
#  '제발 빠른배송좀해주시면 안될까요\n기업은 커지는데, 우선순위가 껍데기보단 제일은 유통망아닐까요 어차피 외주겠지만 물건을 시키고 스트레스받는일없게 빠른배송좀부탁드려요 쓰던거라 그냥귀찮아서 시키긴하지만..\n주문하면서도 언제올까싶은걱정이 드네요']

# %%
a= '안녕하세요'
if '안' in a:
    print('잇다')
# Out:
# 잇다

# %%
tmp=[]
cnt=3
import time
for j in range(2,100):
            if cnt==7:
                selector = '#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > section > div > a.sc-ijnzTp.leYIIS'
                driver.find_element_by_css_selector(selector).click()
            else:
                selector = f'#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > section > div > a:nth-child({cnt})'
                driver.find_element_by_css_selector(selector).click()
#                 print(j)
            if cnt == 7:
                cnt=3
            cnt+=1
            time.sleep(1)
            for i in range(1,11):
                selector = f'#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > div.sc-jPPmml.heYxsi > section:nth-child({i}) > div.sc-gjAXCV.gqHHfv > span'
                text=driver.find_element_by_css_selector(selector).text
#                 print(i)
                if '배달' in text:
                    tmp.append(text)

# %%
tmp
# Out:
# ['무슨 배송이 ㅡㅡ\n탕용기 소 시켰는데\n왜 뚜껑만 배달오죠??\n뚜껑만 사는사람이 어딧나요ㅡㅡ',
#  '배달 빨리 와서 조아요.\n다음에도 이용 합니다.\n감사합니다',
#  '배달하시는분들께 강추 저렴하고 좋아요',
#  '배달은 보통이지만 물품은 잘 받았습니다 수고하세요',
#  '배달용기 사용하는데 엄청 좋네요~ㅎㅎ',
#  '배송은 빵점!! 늦어도 드럽게 늦어서 곤란한 상황이었네요\n택배사를 메이저급에서 중소 택배사로 변경하는걸 신중히 검토 바랍니다\n배송이 늦은게 이번 뿐만이 아닙니다 숱하게 있었습니다\n어떻게 이틀 연속 미배달이라고 배달을 해 주질 않는지...\n물건들은 좋은데...',
#  '배달도 빠르고 조아요오어오',
#  '배달용기로 최고 좋음 싸고 짱',
#  '배달용기로하기 아주 만족합니딘ㅇ',
#  '자영업자 배달하면서 사용하기좋아요',
#  '업소배달용기로 적당합니다',
#  '배달이 늦네요.\n앞전에 주문후 다음날\n요번에는 주문후 3일 오후늦게 기다리다 지쳤네요.\n\n제품은 좋은데.....',
#  '배달이 조금 느려요',
#  '가격/배달/제품 다 만족해용',
#  '배달용기는 이것만쓰네요~~',
#  '배달의민족화이팅입니다',
#  '탕용기 20박스 넘게 구매했는데\n처음으로 리뷰 남기네요\n그만큼 가성비또한 최고겠지요 ^^\n여러 제품들 사용해봤지만\n배달중 제품이 흘렀다는 소리를 들으면\n가슴이 철렁했지만 용기.바꾼후로는 \n마음편히.배달보냅니다\n요즘은 심적인 안정감을 가심비라고 하는데\n가심비 최고에요\n용기란 뚜껑이 아주 딱.맞아 틈이.없습니다\n아주 만족합니다 ',
#  '아주아주 조ㅡ아조아 배달 졸라빨라요',
#  '만족 배달의민족에서 판매하는거라\n왠지 믿음이 생겨서 구매하게되엇는데 역시나\n만족하여 사용했습니다.']

# %%
selector = '#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > section > div > a:nth-child(3)'
driver.find_element_by_css_selector(selector).click()

# %%
selector = '#root > div > div.sc-eNPDpu.iYumKW > section > div.sc-ccLTTT.gZvtiz > div > div.sc-eMRERa.kYTeub > section > div.sc-jPPmml.heYxsi > section:nth-child(1) > div.sc-gjAXCV.gqHHfv > span'
text=driver.find_element_by_css_selector(selector).text
text
# Out:
# '잘 사용하고 있습니다'

# %%
5%5
# Out:
# 0

# %%
driver.get('https://mart.baemin.com/goods/detail/585')
